# %%
from cartpoleenv import CartPoleEnv
import jax
import jax.numpy as jnp

# %%
dt = 0.01
max_steps = 1000
n_poles = 2
env = CartPoleEnv(n_poles, max_steps, dt, render_mode="human")
key = jax.random.PRNGKey(421)
state = jnp.array([0.1, 0, 0, 0, 0, 0])
state, info = env.reset(key, state)

# %%
counter = 0
done = False
while not done:
    action = jnp.array([0.1])
    # action = -0.2*jnp.array([jnp.cos(dt*counter)])
    state, reward, done, truncated, info = env.step(action)
    print(reward)
    env.render()
    counter += 1
env.close()
# Out:
# 0.8999999761581421
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# -0.10000000149011612
# ...
